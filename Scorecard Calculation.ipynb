# %%
 # Assuming each KPI can score between 0 to 10.
    max_score = 10
    if is_higher_better:
        if current_value >= target:
            return max_score
        else:
            return max_score * (current_value / target)
    else:
        if current_value <= target:
            return max_score
        else:
            # Assuming a linear decrease in score for simplicity.
            return max(0, max_score - (current_value - target) / target * max_score)
